# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3.5-mini-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")

messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What about solving an 2x + 3 = 7 equation?"},
]

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
print(output)
# Out:
# [{'generated_text': ' To solve the equation 2x + 3 = 7, follow these steps:\n\nStep 1: Isolate the term with the variable (2x) by subtracting 3 from both sides of the equation.\n2x + 3 - 3 = 7 - 3\n2x = 4\n\nStep 2: Solve for x by dividing both sides of the equation by the coefficient of x, which is 2.\n2x / 2 = 4 / 2\nx = 2\n\nSo, the solution to the equation 2x + 3 = 7 is x = 2.'}]

# %%
type(output)
# Out:
# list

# %%
len(output)
# Out:
# 1

# %%
message = [
    {"role" : "user", "content" : "how to give text file as an input to you phi 3.5 ?"}
]
pipe(message,**generation_args)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7d6fdaad311b> in <cell line: 4>()
#       2     {"role" : "user", "content" : "how to give text file as an input to you phi 3.5 ?"}
#       3 ]
# ----> 4 pipe(message,**generation_args)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     255             # We have one or more prompts in list-of-dicts format, so this is chat mode
#     256             if isinstance(text_inputs[0], dict):
# ...

# %%
message = [
    {"role" : "user", "content" : "how to give text file as an input to you phi 3.5 ?"}
]

# %%
generation_args = {
    "max_new_tokens": 10000,
    "return_full_text": False,
    "do_sample": True,
}

# %%
output = pipe(message,**generation_args)
print(output[0]['generated_text'])
# Out:
#  Phi is an AI natural language understanding platform developed by Microsoft. It's not something you would directly give a text file input to. Instead, when working with Phi for text-based tasks, you would typically use a programming environment or Phi's web interface to interact with the language understanding capabilities.
#
# Here's a general approach using Python, given that Phi has Python SDKs available for developers and researchers:
#
# 1. Install the Phi Python SDK:
#
# ```bash
# pip install phi
# ```
#
# 2. Use the SDK to read a text file and then submit it to Phi for processing:
#
# ```python
# from phi import phi
#
# # Read the contents of your text file
# with open('your_text_file.txt', 'r') as file:
#     text_content = file.read()
#
# # Preprocess the text if necessary: tokenization, lowercasing, etc.
# #...
#
# # Create a Phi session to send your input to Phi
# session = phi.create_session()
#
# # Send the preprocessed text for Phi to understand
# ...

# %%
my_text_file = "/content/The Air (Prevention and Control of Pollution) Act of 1981.txt"

# %%
with open(my_text_file,'r') as file:
  text_con = file.read()

# %%
text_con
# Out:
# '\ufeffTHE AIR (PREVENTION AND CONTROL OF POLLUTION) ACT, 1981 \n____________ \nARRANGEMENT OF SECTIONS \n____________ \nCHAPTER I \nPRELIMINARY \nSECTIONS \n1. Short title, extent and commencement. \n2. Definitions. \nCHAPTER II \nCENTRAL AND STATE BOARDSFOR THE PREVENTION AND CONTROLOF AIR POLLUTION \n3. Central Pollution Control Board. \n4. State Pollution Control Boards constituted under section 4 of Act 6 of 1974 to be State Boards  under this Act. \n5. Constitution of State Boards. \n6. Central Board to exercise the powers and perform the functions of a State Board in the Union  territories. \n7. Terms and conditions of service of members. \n8. Disqualifications. \n9. Vacation of seats by members. \n10. Meetings of Board. \n11. Constitution of committees. \n12. Temporary association of persons with Board for particular purpose. \n13. Vacancy in Board not to invalidate acts or proceedings. \n14. Member-secretary and officers and other employees of State Boards. \n15. Delegation 
# ...

# %%
prompt = "You are tasked with extracting legal information from a given text. Your objective is to identify and extract entire laws, sections, or sub-clauses that appear in the text. The information should be extracted in full, including all references (e.g., section numbers, article numbers) and any associated text. When extracting, follow these guidelines:\
Extract complete sections, articles, or sub-clauses in their entirety.\
Remove subscipts,superscripts or any kind of special characters and produce it as an long sentence\
Remove any kind of footers or the beginning of any other law and produce the clause\
Remove any kind of quotations,numbers and extract only alphabet characters\
Remove any special characters,escape sequences,etc. from the text and generate the output accordingly\
Do not summarize or condense the content;"

# %%
message = [
    {"role" : "user" , "content" : prompt + "your input for the task is" + text_con}
]

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
torch.cuda.empty_cache()

# %%
output = pipe(message,**generation_args)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-44-531541342592> in <cell line: 1>()
# ----> 1 output = pipe(message,**generation_args)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     255             # We have one or more prompts in list-of-dicts format, so this is chat mode
#     256             if isinstance(text_inputs[0], dict):
# --> 257                 return super().__call__(Chat(text_inputs), **kwargs)
#     258             else:
#     259                 chats = [Chat(chat) for chat in text_inputs]  # 🐈 🐈 🐈
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1255             )
#    1256         else:
# ...

# %%
print(output[0]['generated_text'])

# %%
csv_file = "/content/The Air (Prevention and Control of Pollution) Act of 1981.csv"

# %%
import pandas as pd

# %%
data = pd.read_csv(csv_file)

# %%
data.head()
# Out:
#        Type Deontic                                           Sentence
# 0  Flexible     may  Short title, extent and commencement.—(1) This...
# 1     Rigid   shall  \n(3) It shall come into force on such date1as...
# 2  Flexible     may  Definitions.—In this Act, unless the context o...
# 3  Flexible     may  4 \n(j) “emission” means any solid or liquid o...
# 4     Rigid   shall  Central Pollution Control Board.—The Central P...

# %%
text_con_smaller = data["Sentence"]

# %%
text_con_smaller
# Out:
# 0      Short title, extent and commencement.—(1) This...
# 1      \n(3) It shall come into force on such date1as...
# 2      Definitions.—In this Act, unless the context o...
# 3      4 \n(j) “emission” means any solid or liquid o...
# 4      Central Pollution Control Board.—The Central P...
#                              ...
# 132    \n(2) Every rule made by the Central Governmen...
# 133    Power of State Government to make rules.—(1) S...
# 134    \n(2) In particular, and without prejudice to ...
# 135    22 \n(k) the manner in which any area or areas...
# 136    \n(3) After the first constitution of the Stat...
# Name: Sentence, Length: 137, dtype: object

# %%
message = [
    {"role" : "user" , "content" : prompt + "\nyour input for the task is\n" + text_con_smaller[2]}
]

# %%
output = pipe(message,**generation_args)

# %%
print(output[0]['generated_text'])
# Out:
#  In this Act, the definitions are as follows: "air pollutant" means any solid, liquid, or gaseous substance present in the atmosphere in such concentration as may be or tend to be injurious to human beings or other living creatures or plants or property or environment; "air pollution" means the presence in the atmosphere of any air pollutant; "approved appliance" means any equipment or gadget used for bringing any combustible material or generating or consuming any fume, gas of particulate matter and approved by the State Board for the purposes of this Act; "approved fuel" means any fuel approved by the State Board for the purposes of this Act; "automobile" means any vehicle powered either by an internal combustion engine or by any method of generating power to drive such vehicle by burning fuel; "Board" means the Central Board or a State Board; "Central Board" means the Central Pollution Control Board constituted under section 3 of the Water (Prevention and Control of Pollution) Act
# ...
